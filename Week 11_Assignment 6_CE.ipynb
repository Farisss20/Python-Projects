# %% [markdown]
# # Thermal Radiation

# %% [markdown]
# # D1 = 20mm, T1 = 77K , e1 = 0.02
#
# # D2 = 50mm, T2 = 300K, e2 = 0.05
#
# # L = 500mm

# %%
import numpy as np
import math

s = 5.67e-8 ## stefan boltzmann constant
d1 = 0.02
d2 = 0.05
L = 0.5 

A1 = np.pi*d1*L
A2 = np.pi*d2*L

e1 = 0.02
e2 = 0.05

T1 = 77
T2 = 300

q=(s*A1*(T1**4-T2**4))/(((1/e1)+((1-e2)/e2)*(d1/d2)))

print(q)
# Out:
# -0.24940581709365384

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

s = 5.67e-8 ## stefan boltzmann constant
d1 = 0.02
d2 = 0.05
L = 0.5 

A1 = np.pi*d1*L
A2 = np.pi*d2*L

e1 = 0.02
e2 = 0.05

T1 = np.linspace(77,300,223)
T2 = 300

q=(s*A1*(T1**4-T2**4))/(((1/e1)+((1-e2)/e2)*(d1/d2)))

plt.plot(T,q)
plt.title('Thermal Radiation')
plt.xlabel('T Values from 77 to 300')
plt.ylabel('q')
# Out:
# Text(0, 0.5, 'q')
